# %%
import requests

url = "http://127.0.0.1:8000/"

response = requests.get(url)

payload = {
    "name":"hallo",
    "price":294.2,
    "is_offer":True
           }

payload2 = {
    "name":"Bernhard",
    "price":13.1,
    "is_offer":False
           }

payload3 = {
    "name":"Apfel",
    "price":92.22,
    "is_offer":True
           }

anfrage = requests.post(url+"klient", json=payload)
anfrage2 = requests.post(url+"klient", json=payload2)
anfrage3 = requests.post(url+"klient", json=payload3)

print(anfrage.status_code)
print(anfrage.json())
print(anfrage2.status_code)
print(anfrage2.json())
print(anfrage3.status_code)
print(anfrage3.json())
# Out:
# 200
# {'name': 'hallo', 'price': 294.2, 'is_offer': True}
# 200
# {'name': 'popelmann', 'price': 13.1, 'is_offer': False}
# 200
# {'name': 'forz', 'price': 92.22, 'is_offer': True}
